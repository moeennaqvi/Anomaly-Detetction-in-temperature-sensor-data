# %%
# libraries
# %matplotlib notebook

import pandas as pd
import numpy as np
#import scipy as sc
import custom_function as cf

import matplotlib
import seaborn
import matplotlib.dates as md
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.covariance import EllipticEnvelope
from pyemma import msm
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from fbprophet import Prophet

#Extracting data
df = pd.read_csv("realKnownCause/realKnownCause/ambient_temperature_system_failure.csv")

#Understanding data
print(df.info())
# check the timestamp format and frequence 
print(df['timestamp'].head(10))
# check the temperature mean
print(df['value'].mean())
# change the type of timestamp column for plotting
df['timestamp'] = pd.to_datetime(df['timestamp'])
# change fahrenheit to °C (temperature mean= 71 -> fahrenheit)
df['value'] = (df['value'] - 32) * 5/9
# plot the data
df.plot(x='timestamp', y='value')

#Feature Engineering

# the hours and if it's night or day (7:00-22:00)
df['hours'] = df['timestamp'].dt.hour
df['daylight'] = ((df['hours'] >= 7) & (df['hours'] <= 22)).astype(int)
# the day of the week (Monday=0, Sunday=6) and if it's a week end day or week day.
df['DayOfTheWeek'] = df['timestamp'].dt.dayofweek
df['WeekDay'] = (df['DayOfTheWeek'] < 5).astype(int)
# An estimation of anomly population of the dataset (necessary for several algorithm)
outliers_fraction = 0.01
# time with int to plot easily
df['time_epoch'] = (df['timestamp'].astype(np.int64)/100000000000).astype(np.int64)

# creation of 4 distinct categories that seem useful (week end/day week & night/day)
df['categories'] = df['WeekDay']*2 + df['daylight']

a = df.loc[df['categories'] == 0, 'value']
b = df.loc[df['categories'] == 1, 'value']
c = df.loc[df['categories'] == 2, 'value']
d = df.loc[df['categories'] == 3, 'value']

fig, ax = plt.subplots()
a_heights, a_bins = np.histogram(a)
b_heights, b_bins = np.histogram(b, bins=a_bins)
c_heights, c_bins = np.histogram(c, bins=a_bins)
d_heights, d_bins = np.histogram(d, bins=a_bins)

width = (a_bins[1] - a_bins[0])/6

ax.bar(a_bins[:-1], a_heights*100/a.count(), width=width, facecolor='blue', label='WeekEndNight')
ax.bar(b_bins[:-1]+width, (b_heights*100/b.count()), width=width, facecolor='green', label ='WeekEndLight')
ax.bar(c_bins[:-1]+width*2, (c_heights*100/c.count()), width=width, facecolor='red', label ='WeekDayNight')
ax.bar(d_bins[:-1]+width*3, (d_heights*100/d.count()), width=width, facecolor='black', label ='WeekDayLight')

plt.legend()
plt.show()


#Model engineering

#1. Markov Chains (Use for ordered sequential anomalies )
# We need discretize the data points in define states for markov chain. 
# We will just take 'value' to define state for this example and define 5 levels of value (very low, low, average, high, very high)/(VL, L, A, H, VH).
# Markov chain will calculate the probability of sequence like (VL, L, L, A, A, L, A). If the probability is very weak we consider the sequence as an anomaly

# definition of the different state
x1 = (df['value'] <=18).astype(int)
x2= ((df['value'] > 18) & (df['value']<=21)).astype(int)
x3 = ((df['value'] > 21) & (df['value']<=24)).astype(int)
x4 = ((df['value'] > 24) & (df['value']<=27)).astype(int)
x5 = (df['value'] >27).astype(int)
df_mm = x1 + 2*x2 + 3*x3 + 4*x4 + 5*x5

# getting the anomaly labels for our dataset (evaluating sequence of 5 values and anomaly = less than 20% probable)
df_anomaly = cf.markovAnomaly(df_mm, 5, 0.20)
df_anomaly = pd.Series(df_anomaly)
print(df_anomaly.value_counts())

# add the data to the main 
df['anomaly1'] = df_anomaly

# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly1'] == 1, ('time_epoch', 'value')] #anomaly

ax.plot(df['time_epoch'], df['value'], color='blue')
ax.scatter(a['time_epoch'],a['value'], color='red')
plt.show()

# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly1'] == 0, 'value']
b = df.loc[df['anomaly1'] == 1, 'value']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'])
plt.legend()
plt.show()

#2. Isolation Forest (Used for unordered collective anomalies)


# Take useful feature and standardize them 
data = df[['value', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
# train isolation forest 
model =  IsolationForest(contamination = outliers_fraction)
model.fit(data)
# add the data to the main  
df['anomaly2'] = pd.Series(model.predict(data))
df['anomaly2'] = df['anomaly2'].map( {1: 0, -1: 1} )
print(df['anomaly2'].value_counts())

# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly2'] == 1, ['time_epoch', 'value']] #anomaly

ax.plot(df['time_epoch'], df['value'], color='blue')
ax.scatter(a['time_epoch'],a['value'], color='red')
plt.show()

# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly2'] == 0, 'value']
b = df.loc[df['anomaly2'] == 1, 'value']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'])
plt.legend()
plt.show()


#3. One class SVM (Used for unordered collective anomalies)


# Take useful feature and standardize them 
data = df[['value', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
# train one class SVM 
model =  OneClassSVM(nu=0.95 * outliers_fraction) #nu=0.95 * outliers_fraction  + 0.05
data = pd.DataFrame(np_scaled)
model.fit(data)
# add the data to the main  
df['anomaly3'] = pd.Series(model.predict(data))
df['anomaly3'] = df['anomaly3'].map( {1: 0, -1: 1} )
print(df['anomaly3'].value_counts())

# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly3'] == 1, ['time_epoch', 'value']] #anomaly

ax.plot(df['time_epoch'], df['value'], color='blue')
ax.scatter(a['time_epoch'],a['value'], color='red')
plt.show()

# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly3'] == 0, 'value']
b = df.loc[df['anomaly3'] == 1, 'value']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'])
plt.legend()
plt.show()

#4. RNN (used for ordered sequential anomalies)

#select and standardize data
data_n = df[['value', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data_n)
data_n = pd.DataFrame(np_scaled)

# important parameters and train/test size
prediction_time = 1 
testdatasize = 1000
unroll_length = 50
testdatacut = testdatasize + unroll_length  + 1

#train data
x_train = data_n[0:-prediction_time-testdatacut].as_matrix()
y_train = data_n[prediction_time:-testdatacut  ][0].as_matrix()

# test data
x_test = data_n[0-testdatacut:-prediction_time].as_matrix()
y_test = data_n[prediction_time-testdatacut:  ][0].as_matrix()

#unroll: create sequence of 50 previous data points for each data points
def unroll(data,sequence_length=24):
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    return np.asarray(result)

# adapt the datasets for the sequence data shape
x_train = unroll(x_train,unroll_length)
x_test  = unroll(x_test,unroll_length)
y_train = y_train[-x_train.shape[0]:]
y_test  = y_test[-x_test.shape[0]:]

# see the shape
print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)

# specific libraries for RNN
# keras is a high layer build on Tensorflow layer to stay in high level/easy implementation
from keras.layers import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import time #helper libraries
from keras.models import model_from_json
from keras import backend as K

# Build the model

"""
data_dim = x_train.shape[-1]
timesteps = 8

model = Sequential()
model.add(LSTM(100, return_sequences=True,
               input_shape=(timesteps, data_dim)))  # returns a sequence of vectors of dimension 100
model.add(LSTM(100, return_sequences=True))  # returns a sequence of vectors of dimension 100
model.add(LSTM(100))  # return a single vector of dimension 100
model.add(Dense(10, activation='linear'))

model.compile(loss='mse',
              optimizer='rmsprop',
              metrics=['accuracy'])

"""

model = Sequential()

model.add(LSTM(
    input_dim=x_train.shape[-1],
    output_dim=50,
    return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
    100,
    return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(
    output_dim=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')
print('compilation time : {}'.format(time.time() - start))


# Train the model

model.fit(
    x_train,
    y_train,
    batch_size=3028,
    epochs=350,
    validation_split=0.1)



# serialize model to JSON
model_json = model.to_json()
with open("anomalydetectionmodel2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("anomalydetectionmodel2.h5")
print("Saved model to disk")

K.clear_session()

# load json and create model
json_file = open('anomalydetectionmodel2.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("anomalydetectionmodel2.h5")
print("Loaded model from disk")

# create the list of difference between prediction and test data
diff=[]
ratio=[]
p = loaded_model.predict(x_test)
# predictions = lstm.predict_sequences_multiple(loaded_model, x_test, 50, 50)
for u in range(len(y_test)):
    pr = p[u][0]
    ratio.append((y_test[u]/pr)-1)
    diff.append(abs(y_test[u]- pr))
    
# plot the prediction and the reality (for the test data)
fig, axs = plt.subplots()
axs.plot(p,color='red', label='prediction')
axs.plot(y_test,color='blue', label='y_test')
plt.legend(loc='upper left')
plt.show()

# select the most distant prediction/reality data points as anomalies
diff = pd.Series(diff)
number_of_outliers = int(outliers_fraction*len(diff))
threshold = diff.nlargest(number_of_outliers).min()
# data with anomaly label (test data part)
test = (diff >= threshold).astype(int)
# the training data part where we didn't predict anything (overfitting possible): no anomaly
complement = pd.Series(0, index=np.arange(len(data_n)-testdatasize))
# # add the data to the main
df['anomaly4'] = complement.append(test, ignore_index='True')
print(df['anomaly4'].value_counts())

# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly4'] == 1, ['time_epoch', 'value']] #anomaly

ax.plot(df['time_epoch'], df['value'], color='blue')
ax.scatter(a['time_epoch'],a['value'], color='red')
plt.axis([1.370*1e7, 1.405*1e7, 15,30])
plt.show()

# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly4'] == 0, 'value']
b = df.loc[df['anomaly4'] == 1, 'value']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'])
plt.legend()
plt.show()
# Out:
# You are still using msmtools from the deprecated Omnia channel. Please switch to conda-forge to catch future updates.
# In order to do so please set conda-forge channel to highest priority by:
#
#     conda config --add channels conda-forge
#
# and update this package by:
#
#     conda update msmtools
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\pyemma\__init__.py:91: UserWarning: You are not using the latest release of PyEMMA. Latest is 2.5.2, you have 2.4.
#   .format(latest=latest, current=current), category=UserWarning)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
# timestamp    7267 non-null object
# value        7267 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 113.6+ KB
# None
# 0    2013-07-04 00:00:00
# 1    2013-07-04 01:00:00
# 2    2013-07-04 02:00:00
# 3    2013-07-04 03:00:00
# 4    2013-07-04 04:00:00
# 5    2013-07-04 05:00:00
# 6    2013-07-04 06:00:00
# 7    2013-07-04 07:00:00
# 8    2013-07-04 08:00:00
# 9    2013-07-04 09:00:00
# Name: timestamp, dtype: object
# 71.24243270828815
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# 0    7147
# 1     120
# dtype: int64
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# 0    7194
# 1      73
# Name: anomaly2, dtype: int64
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# 0    7198
# 1      69
# Name: anomaly3, dtype: int64
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:204: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:205: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:208: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:209: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# x_train (6165, 50, 5)
# y_train (6165,)
# x_test (1000, 50, 5)
# y_test (1000,)
# Using TensorFlow backend.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:263: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:263: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(units=50, input_shape=(None, 5), return_sequences=True)`
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:272: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
# compilation time : 0.017000913619995117
# Train on 5548 samples, validate on 617 samples
# Epoch 1/350
# 5548/5548 [==============================] - 3s 520us/step - loss: 0.6597 - val_loss: 0.7667
# Epoch 2/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.2271 - val_loss: 0.4451
# Epoch 3/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.1345 - val_loss: 0.3207
# Epoch 4/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.1193 - val_loss: 0.2628
# Epoch 5/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.1066 - val_loss: 0.2086
# Epoch 6/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.1033 - val_loss: 0.1954
# Epoch 7/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0980 - val_loss: 0.1858
# Epoch 8/350
# 5548/5548 [==============================] - 0s 82us/step - loss: 0.0867 - val_loss: 0.1756
# Epoch 9/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0832 - val_loss: 0.1675
# Epoch 10/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0838 - val_loss: 0.1690
# Epoch 11/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0890 - val_loss: 0.1793
# Epoch 12/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0933 - val_loss: 0.1962
# Epoch 13/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0882 - val_loss: 0.1808
# Epoch 14/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0812 - val_loss: 0.1663
# Epoch 15/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0774 - val_loss: 0.1617
# Epoch 16/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0758 - val_loss: 0.1551
# Epoch 17/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0745 - val_loss: 0.1400
# Epoch 18/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0752 - val_loss: 0.1394
# Epoch 19/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0799 - val_loss: 0.1202
# Epoch 20/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0728 - val_loss: 0.1174
# Epoch 21/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0687 - val_loss: 0.1161
# Epoch 22/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0702 - val_loss: 0.1237
# Epoch 23/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0736 - val_loss: 0.1211
# Epoch 24/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0699 - val_loss: 0.1402
# Epoch 25/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0796 - val_loss: 0.1858
# Epoch 26/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0784 - val_loss: 0.1152
# Epoch 27/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0619 - val_loss: 0.1117
# Epoch 28/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0615 - val_loss: 0.1088
# Epoch 29/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0639 - val_loss: 0.1038
# Epoch 30/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0684 - val_loss: 0.0990
# Epoch 31/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0696 - val_loss: 0.1021
# Epoch 32/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0657 - val_loss: 0.1154
# Epoch 33/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0686 - val_loss: 0.1533
# Epoch 34/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0713 - val_loss: 0.1129
# Epoch 35/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0626 - val_loss: 0.1078
# Epoch 36/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0605 - val_loss: 0.1078
# Epoch 37/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0627 - val_loss: 0.1090
# Epoch 38/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0658 - val_loss: 0.0923
# Epoch 39/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0607 - val_loss: 0.0911
# Epoch 40/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0621 - val_loss: 0.0958
# Epoch 41/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0628 - val_loss: 0.0963
# Epoch 42/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0608 - val_loss: 0.1235
# Epoch 43/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0626 - val_loss: 0.1145
# Epoch 44/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0639 - val_loss: 0.1122
# Epoch 45/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0606 - val_loss: 0.1083
# Epoch 46/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0585 - val_loss: 0.0997
# Epoch 47/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0593 - val_loss: 0.0947
# Epoch 48/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0630 - val_loss: 0.0863
# Epoch 49/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0604 - val_loss: 0.0837
# Epoch 50/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0557 - val_loss: 0.0914
# Epoch 51/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0558 - val_loss: 0.1080
# Epoch 52/350
# 5548/5548 [==============================] - 0s 83us/step - loss: 0.0588 - val_loss: 0.1155
# Epoch 53/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0621 - val_loss: 0.0980
# Epoch 54/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0579 - val_loss: 0.0920
# Epoch 55/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0589 - val_loss: 0.0891
# Epoch 56/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0571 - val_loss: 0.0843
# Epoch 57/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0565 - val_loss: 0.0809
# Epoch 58/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0554 - val_loss: 0.0844
# Epoch 59/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0560 - val_loss: 0.0841
# Epoch 60/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0579 - val_loss: 0.1054
# Epoch 61/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0637 - val_loss: 0.1058
# Epoch 62/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0602 - val_loss: 0.0929
# Epoch 63/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0546 - val_loss: 0.0908
# Epoch 64/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0507 - val_loss: 0.0821
# Epoch 65/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0528 - val_loss: 0.0806
# Epoch 66/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0559 - val_loss: 0.0844
# Epoch 67/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0570 - val_loss: 0.0971
# Epoch 68/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0564 - val_loss: 0.1000
# Epoch 69/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0595 - val_loss: 0.1004
# Epoch 70/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0552 - val_loss: 0.0853
# Epoch 71/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0523 - val_loss: 0.0835
# Epoch 72/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0542 - val_loss: 0.0877
# Epoch 73/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0553 - val_loss: 0.0779
# Epoch 74/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0532 - val_loss: 0.0817
# Epoch 75/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0515 - val_loss: 0.0894
# Epoch 76/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0509 - val_loss: 0.1002
# Epoch 77/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0540 - val_loss: 0.1029
# Epoch 78/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0577 - val_loss: 0.0909
# Epoch 79/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0520 - val_loss: 0.0942
# Epoch 80/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0502 - val_loss: 0.0789
# Epoch 81/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0535 - val_loss: 0.0806
# Epoch 82/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0566 - val_loss: 0.0797
# Epoch 83/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0516 - val_loss: 0.0843
# Epoch 84/350
# 5548/5548 [==============================] - 0s 82us/step - loss: 0.0504 - val_loss: 0.1056
# Epoch 85/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0543 - val_loss: 0.1066
# Epoch 86/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0546 - val_loss: 0.0883
# Epoch 87/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0511 - val_loss: 0.0791
# Epoch 88/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0522 - val_loss: 0.0783
# Epoch 89/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0520 - val_loss: 0.0798
# Epoch 90/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0498 - val_loss: 0.0795
# Epoch 91/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0504 - val_loss: 0.0857
# Epoch 92/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0519 - val_loss: 0.0959
# Epoch 93/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0524 - val_loss: 0.0966
# Epoch 94/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0523 - val_loss: 0.0895
# Epoch 95/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0500 - val_loss: 0.0793
# Epoch 96/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0486 - val_loss: 0.0790
# Epoch 97/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0489 - val_loss: 0.0802
# Epoch 98/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0507 - val_loss: 0.0812
# Epoch 99/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0520 - val_loss: 0.0777
# Epoch 100/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0511 - val_loss: 0.0801
# Epoch 101/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0510 - val_loss: 0.0789
# Epoch 102/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0496 - val_loss: 0.0752
# Epoch 103/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0466 - val_loss: 0.0773
# Epoch 104/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0469 - val_loss: 0.0955
# Epoch 105/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0526 - val_loss: 0.1255
# Epoch 106/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0536 - val_loss: 0.0912
# Epoch 107/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0521 - val_loss: 0.0847
# Epoch 108/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0488 - val_loss: 0.0825
# Epoch 109/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0473 - val_loss: 0.0780
# Epoch 110/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0499 - val_loss: 0.0724
# Epoch 111/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0492 - val_loss: 0.0846
# Epoch 112/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0505 - val_loss: 0.0985
# Epoch 113/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0501 - val_loss: 0.0928
# Epoch 114/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0487 - val_loss: 0.0881
# Epoch 115/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0508 - val_loss: 0.0835
# Epoch 116/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0508 - val_loss: 0.0806
# Epoch 117/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0473 - val_loss: 0.0805
# Epoch 118/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0461 - val_loss: 0.0734
# Epoch 119/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0466 - val_loss: 0.0727
# Epoch 120/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0479 - val_loss: 0.0744
# Epoch 121/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0466 - val_loss: 0.0786
# Epoch 122/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0477 - val_loss: 0.0879
# Epoch 123/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0535 - val_loss: 0.1096
# Epoch 124/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0557 - val_loss: 0.0818
# Epoch 125/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0471 - val_loss: 0.0744
# Epoch 126/350
# 5548/5548 [==============================] - 0s 82us/step - loss: 0.0454 - val_loss: 0.0753
# Epoch 127/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0438 - val_loss: 0.0840
# Epoch 128/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0459 - val_loss: 0.0942
# Epoch 129/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0466 - val_loss: 0.1008
# Epoch 130/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0459 - val_loss: 0.0917
# Epoch 131/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0472 - val_loss: 0.0997
# Epoch 132/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0537 - val_loss: 0.0859
# Epoch 133/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0509 - val_loss: 0.0831
# Epoch 134/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0455 - val_loss: 0.0805
# Epoch 135/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0452 - val_loss: 0.0847
# Epoch 136/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0458 - val_loss: 0.0951
# Epoch 137/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0496 - val_loss: 0.0867
# Epoch 138/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0468 - val_loss: 0.0767
# Epoch 139/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0464 - val_loss: 0.0768
# Epoch 140/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0461 - val_loss: 0.0748
# Epoch 141/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0455 - val_loss: 0.0898
# Epoch 142/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0487 - val_loss: 0.0932
# Epoch 143/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0489 - val_loss: 0.0889
# Epoch 144/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0468 - val_loss: 0.0844
# Epoch 145/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0451 - val_loss: 0.0815
# Epoch 146/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0455 - val_loss: 0.0820
# Epoch 147/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0502 - val_loss: 0.0965
# Epoch 148/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0506 - val_loss: 0.0799
# Epoch 149/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0462 - val_loss: 0.0778
# Epoch 150/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0467 - val_loss: 0.0856
# Epoch 151/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0462 - val_loss: 0.0918
# Epoch 152/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0453 - val_loss: 0.0860
# Epoch 153/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0457 - val_loss: 0.0893
# Epoch 154/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0437 - val_loss: 0.0842
# Epoch 155/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0446 - val_loss: 0.0920
# Epoch 156/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0463 - val_loss: 0.0890
# Epoch 157/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0486 - val_loss: 0.0785
# Epoch 158/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0486 - val_loss: 0.0865
# Epoch 159/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0454 - val_loss: 0.0821
# Epoch 160/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0454 - val_loss: 0.0722
# Epoch 161/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0451 - val_loss: 0.0738
# Epoch 162/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0448 - val_loss: 0.0746
# Epoch 163/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0467 - val_loss: 0.0961
# Epoch 164/350
# 5548/5548 [==============================] - 0s 82us/step - loss: 0.0492 - val_loss: 0.0870
# Epoch 165/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0464 - val_loss: 0.0886
# Epoch 166/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0450 - val_loss: 0.0795
# Epoch 167/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0433 - val_loss: 0.0832
# Epoch 168/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0448 - val_loss: 0.0857
# Epoch 169/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0479 - val_loss: 0.0852
# Epoch 170/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0475 - val_loss: 0.0801
# Epoch 171/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0463 - val_loss: 0.0788
# Epoch 172/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0457 - val_loss: 0.0773
# Epoch 173/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0448 - val_loss: 0.0793
# Epoch 174/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0453 - val_loss: 0.0789
# Epoch 175/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0449 - val_loss: 0.0815
# Epoch 176/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0449 - val_loss: 0.0826
# Epoch 177/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0463 - val_loss: 0.0899
# Epoch 178/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0465 - val_loss: 0.0957
# Epoch 179/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0460 - val_loss: 0.0885
# Epoch 180/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0449 - val_loss: 0.0815
# Epoch 181/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0445 - val_loss: 0.0736
# Epoch 182/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0454 - val_loss: 0.0715
# Epoch 183/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0433 - val_loss: 0.0768
# Epoch 184/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0421 - val_loss: 0.0810
# Epoch 185/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0464 - val_loss: 0.1029
# Epoch 186/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0466 - val_loss: 0.0851
# Epoch 187/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0457 - val_loss: 0.0805
# Epoch 188/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0456 - val_loss: 0.0749
# Epoch 189/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0437 - val_loss: 0.0814
# Epoch 190/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0445 - val_loss: 0.0777
# Epoch 191/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0448 - val_loss: 0.0779
# Epoch 192/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0441 - val_loss: 0.0909
# Epoch 193/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0447 - val_loss: 0.0873
# Epoch 194/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0429 - val_loss: 0.0789
# Epoch 195/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0434 - val_loss: 0.0789
# Epoch 196/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0462 - val_loss: 0.0857
# Epoch 197/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0485 - val_loss: 0.0831
# Epoch 198/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0451 - val_loss: 0.0789
# Epoch 199/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0425 - val_loss: 0.0798
# Epoch 200/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0429 - val_loss: 0.0907
# Epoch 201/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0427 - val_loss: 0.0970
# Epoch 202/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0444 - val_loss: 0.0863
# Epoch 203/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0429 - val_loss: 0.0768
# Epoch 204/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0448 - val_loss: 0.0756
# Epoch 205/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0475 - val_loss: 0.0775
# Epoch 206/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0428 - val_loss: 0.0818
# Epoch 207/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0443 - val_loss: 0.0863
# Epoch 208/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0460 - val_loss: 0.0795
# Epoch 209/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0435 - val_loss: 0.0772
# Epoch 210/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0418 - val_loss: 0.0822
# Epoch 211/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0412 - val_loss: 0.0781
# Epoch 212/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0418 - val_loss: 0.0766
# Epoch 213/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0427 - val_loss: 0.0856
# Epoch 214/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0456 - val_loss: 0.0954
# Epoch 215/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0493 - val_loss: 0.0861
# Epoch 216/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0440 - val_loss: 0.0789
# Epoch 217/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0426 - val_loss: 0.0703
# Epoch 218/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0419 - val_loss: 0.0731
# Epoch 219/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0433 - val_loss: 0.0725
# Epoch 220/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0413 - val_loss: 0.0758
# Epoch 221/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0430 - val_loss: 0.0744
# Epoch 222/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0447 - val_loss: 0.0791
# Epoch 223/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0458 - val_loss: 0.0787
# Epoch 224/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0433 - val_loss: 0.0779
# Epoch 225/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0431 - val_loss: 0.0807
# Epoch 226/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0430 - val_loss: 0.0737
# Epoch 227/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0433 - val_loss: 0.0744
# Epoch 228/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0446 - val_loss: 0.0760
# Epoch 229/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0431 - val_loss: 0.0760
# Epoch 230/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0420 - val_loss: 0.0776
# Epoch 231/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0427 - val_loss: 0.0793
# Epoch 232/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0449 - val_loss: 0.0820
# Epoch 233/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0453 - val_loss: 0.0771
# Epoch 234/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0433 - val_loss: 0.0760
# Epoch 235/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0426 - val_loss: 0.0746
# Epoch 236/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0437 - val_loss: 0.0751
# Epoch 237/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0432 - val_loss: 0.0765
# Epoch 238/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0442 - val_loss: 0.0771
# Epoch 239/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0420 - val_loss: 0.0750
# Epoch 240/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0423 - val_loss: 0.0767
# Epoch 241/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0442 - val_loss: 0.0739
# Epoch 242/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0439 - val_loss: 0.0733
# Epoch 243/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0418 - val_loss: 0.0762
# Epoch 244/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0414 - val_loss: 0.0793
# Epoch 245/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0439 - val_loss: 0.0802
# Epoch 246/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0456 - val_loss: 0.0793
# Epoch 247/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0445 - val_loss: 0.0738
# Epoch 248/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0418 - val_loss: 0.0757
# Epoch 249/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0422 - val_loss: 0.0743
# Epoch 250/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0416 - val_loss: 0.0737
# Epoch 251/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0441 - val_loss: 0.0748
# Epoch 252/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0436 - val_loss: 0.0766
# Epoch 253/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0426 - val_loss: 0.0747
# Epoch 254/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0408 - val_loss: 0.0748
# Epoch 255/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0402 - val_loss: 0.0736
# Epoch 256/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0402 - val_loss: 0.0757
# Epoch 257/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0418 - val_loss: 0.0759
# Epoch 258/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0485 - val_loss: 0.0814
# Epoch 259/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0464 - val_loss: 0.0765
# Epoch 260/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0408 - val_loss: 0.0756
# Epoch 261/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0413 - val_loss: 0.0750
# Epoch 262/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0422 - val_loss: 0.0754
# Epoch 263/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0423 - val_loss: 0.0781
# Epoch 264/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0426 - val_loss: 0.0777
# Epoch 265/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0443 - val_loss: 0.0757
# Epoch 266/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0420 - val_loss: 0.0771
# Epoch 267/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0424 - val_loss: 0.0756
# Epoch 268/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0404 - val_loss: 0.0758
# Epoch 269/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0404 - val_loss: 0.0803
# Epoch 270/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0408 - val_loss: 0.0758
# Epoch 271/350
# 5548/5548 [==============================] - 0s 84us/step - loss: 0.0420 - val_loss: 0.0730
# Epoch 272/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0440 - val_loss: 0.0780
# Epoch 273/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0467 - val_loss: 0.0754
# Epoch 274/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0425 - val_loss: 0.0761
# Epoch 275/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0414 - val_loss: 0.0741
# Epoch 276/350
# 5548/5548 [==============================] - 0s 84us/step - loss: 0.0406 - val_loss: 0.0746
# Epoch 277/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0423 - val_loss: 0.0799
# Epoch 278/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0431 - val_loss: 0.0762
# Epoch 279/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0432 - val_loss: 0.0811
# Epoch 280/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0429 - val_loss: 0.0784
# Epoch 281/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0412 - val_loss: 0.0755
# Epoch 282/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0405 - val_loss: 0.0778
# Epoch 283/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0426 - val_loss: 0.0766
# Epoch 284/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0426 - val_loss: 0.0730
# Epoch 285/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0391 - val_loss: 0.0766
# Epoch 286/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0396 - val_loss: 0.0734
# Epoch 287/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0401 - val_loss: 0.0730
# Epoch 288/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0417 - val_loss: 0.0738
# Epoch 289/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0447 - val_loss: 0.0768
# Epoch 290/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0466 - val_loss: 0.0804
# Epoch 291/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0426 - val_loss: 0.0757
# Epoch 292/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0399 - val_loss: 0.0760
# Epoch 293/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0415 - val_loss: 0.0801
# Epoch 294/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0403 - val_loss: 0.0758
# Epoch 295/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0398 - val_loss: 0.0736
# Epoch 296/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0413 - val_loss: 0.0797
# Epoch 297/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0468 - val_loss: 0.0807
# Epoch 298/350
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0442 - val_loss: 0.0763
# Epoch 299/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0430 - val_loss: 0.0742
# Epoch 300/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0418 - val_loss: 0.0728
# Epoch 301/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0397 - val_loss: 0.0759
# Epoch 302/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0397 - val_loss: 0.0729
# Epoch 303/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0392 - val_loss: 0.0762
# Epoch 304/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0399 - val_loss: 0.0739
# Epoch 305/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0393 - val_loss: 0.0753
# Epoch 306/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0404 - val_loss: 0.0791
# Epoch 307/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0454 - val_loss: 0.0803
# Epoch 308/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0454 - val_loss: 0.0795
# Epoch 309/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0423 - val_loss: 0.0763
# Epoch 310/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0413 - val_loss: 0.0772
# Epoch 311/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0417 - val_loss: 0.0723
# Epoch 312/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0402 - val_loss: 0.0751
# Epoch 313/350
# 5548/5548 [==============================] - 0s 80us/step - loss: 0.0417 - val_loss: 0.0745
# Epoch 314/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0420 - val_loss: 0.0746
# Epoch 315/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0420 - val_loss: 0.0767
# Epoch 316/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0419 - val_loss: 0.0802
# Epoch 317/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0425 - val_loss: 0.0778
# Epoch 318/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0426 - val_loss: 0.0758
# Epoch 319/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0412 - val_loss: 0.0739
# Epoch 320/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0399 - val_loss: 0.0741
# Epoch 321/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0407 - val_loss: 0.0760
# Epoch 322/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0429 - val_loss: 0.0768
# Epoch 323/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0406 - val_loss: 0.0746
# Epoch 324/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0410 - val_loss: 0.0769
# Epoch 325/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0426 - val_loss: 0.0762
# Epoch 326/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0409 - val_loss: 0.0776
# Epoch 327/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0414 - val_loss: 0.0792
# Epoch 328/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0400 - val_loss: 0.0784
# Epoch 329/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0411 - val_loss: 0.0806
# Epoch 330/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0418 - val_loss: 0.0746
# Epoch 331/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0402 - val_loss: 0.0736
# Epoch 332/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0420 - val_loss: 0.0763
# Epoch 333/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0439 - val_loss: 0.0768
# Epoch 334/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0424 - val_loss: 0.0785
# Epoch 335/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0416 - val_loss: 0.0781
# Epoch 336/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0399 - val_loss: 0.0771
# Epoch 337/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0388 - val_loss: 0.0795
# Epoch 338/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0393 - val_loss: 0.0770
# Epoch 339/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0403 - val_loss: 0.0713
# Epoch 340/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0393 - val_loss: 0.0759
# Epoch 341/350
# 5548/5548 [==============================] - 0s 78us/step - loss: 0.0388 - val_loss: 0.0780
# Epoch 342/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0416 - val_loss: 0.1161
# Epoch 343/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0482 - val_loss: 0.0827
# Epoch 344/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0442 - val_loss: 0.0784
# Epoch 345/350
# 5548/5548 [==============================] - 0s 75us/step - loss: 0.0392 - val_loss: 0.0769
# Epoch 346/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0392 - val_loss: 0.0769
# Epoch 347/350
# 5548/5548 [==============================] - 0s 77us/step - loss: 0.0386 - val_loss: 0.0782
# Epoch 348/350
# 5548/5548 [==============================] - 0s 76us/step - loss: 0.0393 - val_loss: 0.0811
# Epoch 349/350
# 5548/5548 [==============================] - 0s 79us/step - loss: 0.0402 - val_loss: 0.0930
# Epoch 350/350
# 5548/5548 [==============================] - 0s 81us/step - loss: 0.0433 - val_loss: 0.0940
# Saved model to disk
# Loaded model from disk
# <img src="data:image/png;base64,..." width="640">
# 0    7257
# 1      10
# Name: anomaly4, dtype: int64
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
